# %% [markdown]
# # Exploration MDE

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from pathlib import Path

# %%
project_path = Path().cwd().parent.parent
data_path = project_path / "data"

# %%
df = pd.read_csv(data_path / "movies_details.csv")
df.head(3)
# Out:
#       budget                                    genres      id  \
# 0  237000000  Action-Adventure-Fantasy-Science Fiction   19995
# 1  300000000                  Adventure-Fantasy-Action     285
# 2  245000000                    Action-Adventure-Crime  206647
#
#                                             keywords original_language  \
# 0  culture clash-future-space war-space colony-so...                en
# 1  ocean-drug abuse-exotic island-east india trad...                en
# 2  spy-based on novel-secret agent-sequel-mi6-bri...                en
#
#                              original_title  popularity release_date  \
# 0                                    Avatar  150.437577   2009-12-10
# 1  Pirates of the Caribbean: At World's End  139.082615   2007-05-19
# 2                                   Spectre  107.376788   2015-10-26
#
#       revenue  runtime                           spoken_languages    status  \
# ...

# %%
g = sns.pairplot(df, vars=["budget", "revenue", "popularity"])

# %%
pd.DataFrame(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   budget             4803 non-null   int64
#  1   genres             4775 non-null   object
#  2   id                 4803 non-null   int64
#  3   keywords           4391 non-null   object
#  4   original_language  4803 non-null   object
#  5   original_title     4803 non-null   object
#  6   popularity         4803 non-null   float64
#  7   release_date       4802 non-null   object
#  8   revenue            4803 non-null   int64
#  9   runtime            4801 non-null   float64
#  10  spoken_languages   4716 non-null   object
#  11  status             4803 non-null   object
#  12  title              4803 non-null   object
#  13  vote_average       4803 non-null   float64
#  14  vote_count         4803 non-null   int64
# dtypes: float64(3), int64(4), object(8)
# ...

# %%
data_gender = data_path / "gender.csv"
data_gender
# Out:
# PosixPath('/home/mde/Documents/IGR204-Data_Visualisation/data/gender.csv')

# %%
gender_df = pd.read_csv(data_gender)
gender_df.name.unique()
# Out:
# array(['Documentary', 'Drama', 'Fantasy', 'Mystery', 'Adventure',
#        'Horror', 'Romance', 'War', 'Crime', 'Action', 'History',
#        'Animation', 'Western', 'Comedy', 'Family', 'TV Movie',
#        'Science Fiction', 'Foreign', 'Music', 'Thriller'], dtype=object)
